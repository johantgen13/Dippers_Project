# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import pandas as pd
import os
import numpy as np
import math
import scipy

# %%
#Defining the read_lightcurve function. This function reads data files and imports them
def read_lightcurve(asas_sn_id, guide = 'known_dipper_lightcurves/'):
    """
    Input: 
        asas_sn_id: the asassn id of the desired star
        guide: the path to the data file of the desired star

    Output: 
        dfv: This is the dataframe for the V-band data of the star
        dfg: This is the dataframe for the g-band data of the star
    
    This function reads the data of the desired star by going to the corresponding file and copying the data of that file onto 
    a data frame. This data frame is then sorted into two data frames by comparing the value in the Photo filter column. If the
    Photo filter column data has a value of one, its row is sorted into the data frame corresponding to the V-band. If the Photo
    filter column data has a value of zero, it gets sorted into the data frame corresponding to the g-band.
    """
    fname = os.path.join(guide, str(asas_sn_id)+'.dat')

    dfv = pd.DataFrame()
    dfg = pd.DataFrame()

    fdata = pd.read_fwf(fname, header=None)
    fdata.columns = ["JD", "Mag", "Mag_err", "Quality", "Cam_number", "Phot_filter", "Camera"] #These are the columns of data

    dfv = fdata.loc[fdata["Phot_filter"] == 1].reset_index(drop=True) #This sorts the data into the V-band
    dfg = fdata.loc[fdata["Phot_filter"] == 0].reset_index(drop=True) #This sorts the data into the g-band

    return dfv, dfg
#End of read_lightcurve function

# %%
def year_to_jd(year):
    jd_epoch = 2449718.5 - (2.458 * 10 **6)
    year_epoch = 1995
    days_in_year = 365.25
    return (year-year_epoch)*days_in_year + jd_epoch-2450000

# %%
def jd_to_year(jd):
    jd_epoch = 2449718.5 - (2.458 * 10 **6)
    year_epoch = 1995
    days_in_year = 365.25
    return year_epoch + (jd - jd_epoch) / days_in_year

# %%
colors = ["#6b8bcd", "#b3b540", "#8f62ca", "#5eb550", "#c75d9c", "#4bb092", "#c5562f", "#6c7f39", 
              "#ce5761", "#c68c45", '#b5b246', '#d77fcc', '#7362cf', '#ce443f', '#3fc1bf', '#cda735',
              '#a1b055']

# %%
J0607v, J0607g = read_lightcurve(377958261591, 'Updated_LC_data/')

J0607g['Mag'].astype(float)

mean0607 = np.mean(J0607g['Mag'])

J0607_mag_avg = [i - mean0607 for i in J0607g['Mag']]

peaks_J0607 = scipy.signal.find_peaks(J0607_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J0607 = peaks_J0607[0]

peak_J0607 = [int(i) for i in peak_J0607]

peak_J0607 = pd.Series(peak_J0607)

# %%
J0727v, J0727g = read_lightcurve(438086977939, 'Updated_LC_data/')

J0727g['Mag'].astype(float)

mean0727 = np.mean(J0727g['Mag'])

J0727_mag_avg = [i - mean0727 for i in J0727g['Mag']]

peaks_J0727 = scipy.signal.find_peaks(J0727_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J0727 = peaks_J0727[0]

peak_J0727 = [int(i) for i in peak_J0727]

peak_J0727 = pd.Series(peak_J0727)

# %%
J0716v, J0716g = read_lightcurve(360777377116, 'Updated_LC_data/')

J0716g['Mag'].astype(float)

mean0716 = np.mean(J0716g['Mag'])

J0716_mag_avg = [i - mean0716 for i in J0716g['Mag']]

peaks_J0716 = scipy.signal.find_peaks(J0716_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J0716 = peaks_J0716[0]

peak_J0716 = [int(i) for i in peak_J0716]

peak_J0716 = pd.Series(peak_J0716)

# %%
J0954v, J0954g = read_lightcurve(635655234580, 'Updated_LC_data/')

J0954g['Mag'].astype(float)

mean0954 = np.mean(J0954g['Mag'])

J0954_mag_avg = [i - mean0954 for i in J0954g['Mag']]

peaks_J0954 = scipy.signal.find_peaks(J0954_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J0954 = peaks_J0954[0]

peak_J0954 = [int(i) for i in peak_J0954]

peak_J0954 = pd.Series(peak_J0954)

# %%
J1644v, J1644g = read_lightcurve(412317159120, 'Updated_LC_data/')

J1644g['Mag'].astype(float)

mean1644 = np.mean(J1644g['Mag'])

J1644_mag_avg = [i - mean1644 for i in J1644g['Mag']]

peaks_J1644 = scipy.signal.find_peaks(J1644_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J1644 = peaks_J1644[0]

peak_J1644 = [int(i) for i in peak_J1644]

peak_J1644 = pd.Series(peak_J1644)

# %%
J1817v, J1817g = read_lightcurve(317827964025, 'Updated_LC_data/')

J1817g['Mag'].astype(float)

mean1817 = np.mean(J1817g['Mag'])

J1817_mag_avg = [i - mean1817 for i in J1817g['Mag']]

peaks_J1817 = scipy.signal.find_peaks(J1817_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J1817 = peaks_J1817[0]

peak_J1817 = [int(i) for i in peak_J1817]

peak_J1817 = pd.Series(peak_J1817)

# %%
J1831v, J1831g = read_lightcurve(438086901547, 'Updated_LC_data/')

J1831g['Mag'].astype(float)

mean1831 = np.mean(J1831g['Mag'])

J1831_mag_avg = [i - mean1831 for i in J1831g['Mag']]

peaks_J1831 = scipy.signal.find_peaks(J1831_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J1831 = peaks_J1831[0]

peak_J1831 = [int(i) for i in peak_J1831]

peak_J1831 = pd.Series(peak_J1831)

# %%
J1919v, J1919g = read_lightcurve(515396514761, 'Updated_LC_data/')

J1919g['Mag'].astype(float)

mean1919 = np.mean(J1919g['Mag'])

J1919_mag_avg = [i - mean1919 for i in J1919g['Mag']]

peaks_J1919 = scipy.signal.find_peaks(J1919_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J1919 = peaks_J1919[0]

peak_J1919 = [int(i) for i in peak_J1919]

peak_J1919 = pd.Series(peak_J1919)

# %%
J2071v, J2071g = read_lightcurve(463856535113, 'Updated_LC_data/')

J2071g['Mag'].astype(float)

mean2071 = np.mean(J2071g['Mag'])

J2071_mag_avg = [i - mean2071 for i in J2071g['Mag']]

peaks_J2071 = scipy.signal.find_peaks(J2071_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J2071 = peaks_J2071[0]

peak_J2071 = [int(i) for i in peak_J2071]

peak_J2071 = pd.Series(peak_J2071)

# %%
J2148v, J2148g = read_lightcurve(120259184943, 'Updated_LC_data/')

J2148g['Mag'].astype(float)

mean2148 = np.mean(J2148g['Mag'])

J2148_mag_avg = [i - mean2148 for i in J2148g['Mag']]

peaks_J2148 = scipy.signal.find_peaks(J2148_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J2148 = peaks_J2148[0]

peak_J2148 = [int(i) for i in peak_J2148]

peak_J2148 = pd.Series(peak_J2148)

# %%
J225623v, J225623g = read_lightcurve(25770019815, 'Updated_LC_data/')

J225623g['Mag'].astype(float)

mean225623 = np.mean(J225623g['Mag'])

J225623_mag_avg = [i - mean225623 for i in J225623g['Mag']]

peaks_J225623 = scipy.signal.find_peaks(J225623_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J225623 = peaks_J225623[0]

peak_J225623 = [int(i) for i in peak_J225623]

peak_J225623 = pd.Series(peak_J225623)

# %%
J1262v, J1262g = read_lightcurve(515397118400, 'Updated_LC_data/')

J1262g['Mag'].astype(float)

mean1262 = np.mean(J1262g['Mag'])

J1262_mag_avg = [i - mean1262 for i in J1262g['Mag']]

peaks_J1262 = scipy.signal.find_peaks(J1262_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J1262 = peaks_J1262[0]

peak_J1262 = [int(i) for i in peak_J1262]

peak_J1262 = pd.Series(peak_J1262)

# %%
J1657v, J1657g = read_lightcurve(661425129485, 'Updated_LC_data/')

J1657g['Mag'].astype(float)

mean1657 = np.mean(J1657g['Mag'])

J1657_mag_avg = [i - mean1657 for i in J1657g['Mag']]

peaks_J1657 = scipy.signal.find_peaks(J1657_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J1657 = peaks_J1657[0]

peak_J1657 = [int(i) for i in peak_J1657]

peak_J1657 = pd.Series(peak_J1657)

# %%
J1712v, J1712g = read_lightcurve(326417831663, 'Updated_LC_data/')

J1712g['Mag'].astype(float)

mean1712 = np.mean(J1712g['Mag'])

J1712_mag_avg = [i - mean1712 for i in J1712g['Mag']]

peaks_J1712 = scipy.signal.find_peaks(J1712_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J1712 = peaks_J1712[0]

peak_J1712 = [int(i) for i in peak_J1712]

peak_J1712 = pd.Series(peak_J1712)

# %%
J0415v, J0415g = read_lightcurve(377957522430, 'Updated_LC_data/')

J0415g['Mag'].astype(float)

mean0415 = np.mean(J0415g['Mag'])

J0415_mag_avg = [i - mean0415 for i in J0415g['Mag']]

peaks_J0415 = scipy.signal.find_peaks(J0415_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J0415 = peaks_J0415[0]

peak_J0415 = [int(i) for i in peak_J0415]

peak_J0415 = pd.Series(peak_J0415)

# %%
J0826v, J0826g = read_lightcurve(601296043597, 'Updated_LC_data/')

J0826g['Mag'].astype(float)

mean0826 = np.mean(J0826g['Mag'])

J0826_mag_avg = [i - mean0826 for i in J0826g['Mag']]

peaks_J0826 = scipy.signal.find_peaks(J0826_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J0826 = peaks_J0826[0]

peak_J0826 = [int(i) for i in peak_J0826]

peak_J0826 = pd.Series(peak_J0826)

# %%
J1734v, J1734g = read_lightcurve(223339338105, 'Updated_LC_data/')

J1734g['Mag'].astype(float)

mean1734 = np.mean(J1734g['Mag'])

J1734_mag_avg = [i - mean1734 for i in J1734g['Mag']]

peaks_J1734 = scipy.signal.find_peaks(J1734_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J1734 = peaks_J1734[0]

peak_J1734 = [int(i) for i in peak_J1734]

peak_J1734 = pd.Series(peak_J1734)

# %%
J2038v, J2038g = read_lightcurve(42950993887, 'Updated_LC_data/')

J2038g['Mag'].astype(float)

mean2038 = np.mean(J2038g['Mag'])

J2038_mag_avg = [i - mean2038 for i in J2038g['Mag']]

peaks_J2038 = scipy.signal.find_peaks(J2038_mag_avg, prominence=0.17, distance=25, height=0.3, width=2) 

peak_J2038 = peaks_J2038[0]

peak_J2038 = [int(i) for i in peak_J2038]

peak_J2038 = pd.Series(peak_J2038)

# %%
fig = plt.figure(figsize=(24,28))
gs = fig.add_gridspec(6,3,hspace=0,wspace=0)
ax = gs.subplots(sharex=True,sharey=False)

padnum = -50

titlesize = 18

# Subfig 1 (J062510-075341)	(377958261591)
cams = J0607g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ0607 = J0607g.loc[J0607g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ0607["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ0607["Mag"].astype(float)
    ax[0,0].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J0607)):
 #   ax[0,0].vlines((J0607g.JD[peak_J0607[i]] - (2.458 * 10**6)), 13.25, (max(J0607g['Mag'])+0.1), "k", alpha=0.4)

ax[0,0].set_title('J062510-075341', y=1.0, pad=padnum, size=titlesize)
ax[0,0].set_xlim(-350,2700)
ax[0,0].set_ylim(13.25,(max(J0607g['Mag'])+0.1))
ax[0,0].set_yticks(np.linspace(13.4, 14.1, 8))

# Subfig 2 (J073924-272916)	(438086977939)
cams = J0727g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ0727 = J0727g.loc[J0727g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ0727["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ0727["Mag"].astype(float)
    ax[0,1].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J0727)):
 #   ax[0,1].vlines((J0727g.JD[peak_J0727[i]] - (2.458 * 10**6)), 12.7, (max(J0727g['Mag'])+0.1), "k", alpha=0.4)

ax[0,1].set_title('J073924-272916', y=1.0, pad=padnum, size=titlesize)
ax[0,1].set_ylim(12.7,(max(J0727g['Mag'])+0.1))
ax[0,1].set_yticks(np.linspace(12.8, 13.3, 6))

# Subfig 3 (J074007-161608)	(360777377116)
J0716g = J0716g.loc[J0716g['Mag'] < 13.75].reset_index(drop=True)

cams = J0716g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ0716 = J0716g.loc[J0716g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ0716["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ0716["Mag"].astype(float)
    ax[0,2].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J0716)-1):
 #   ax[0,2].vlines((J0716g.JD[peak_J0716[i]] - (2.458 * 10**6)), 12.8, (max(J0716g['Mag'])+0.1), "k", alpha=0.4)

ax[0,2].set_title('J074007-161608', y=1.0, pad=padnum, size=titlesize)
ax[0,2].set_ylim(12.8,(max(J0716g['Mag'])+0.1))
ax[0,2].set_yticks(np.linspace(12.9, 13.4, 6))

# Subfig 4 (J094848-545959)	(635655234580)
cams = J0954g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ0954 = J0954g.loc[J0954g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ0954["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ0954["Mag"].astype(float)
    ax[1,0].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J0954)):
 #   ax[1,0].vlines((J0954g.JD[peak_J0954[i]] - (2.458 * 10**6)), 12.8, (max(J0954g['Mag'])+0.15), "k", alpha=0.4)

ax[1,0].set_title('J094848-545959', y=1.0, pad=padnum, size=titlesize)
ax[1,0].set_ylim(12.8,(max(J0954g['Mag'])+0.15))
ax[1,0].set_yticks(np.linspace(12.9, 13.4, 6))

# Subfig 5 (J162209-444247)	(412317159120)
cams = J1644g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ1644 = J1644g.loc[J1644g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ1644["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ1644["Mag"].astype(float)
    ax[1,1].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J1644)):
 #   ax[1,1].vlines((J1644g.JD[peak_J1644[i]] - (2.458 * 10**6)), 13.5, (max(J1644g['Mag'])+0.2), "k", alpha=0.4)

ax[1,1].set_title('J162209-444247', y=1.0, pad=padnum, size=titlesize)
ax[1,1].set_ylim(13.5,(max(J1644g['Mag'])+0.2))
ax[1,1].set_yticks(np.linspace(13.7, 14.5, 5))

# Subfig 6 (J183210-173432)	(317827964025)
cams = J1817g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ1817 = J1817g.loc[J1817g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ1817["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ1817["Mag"].astype(float)
    ax[1,2].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J1817)):
 #   ax[1,2].vlines((J1817g.JD[peak_J1817[i]] - (2.458 * 10**6)), 12.5, (max(J1817g['Mag'])+0.1), "k", alpha=0.4)

ax[1,2].set_title('J183210-173432', y=1.0, pad=padnum, size=titlesize)
ax[1,2].set_ylim(12.5,(max(J1817g['Mag'])+0.1))
ax[1,2].set_yticks(np.linspace(12.6, 13, 5))

# Subfig 7 (J183606-314826)	(438086901547)
J1831g = J1831g.loc[J1831g['Mag'] < 14.5].reset_index(drop=True)

cams = J1831g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ1831 = J1831g.loc[J1831g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ1831["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ1831["Mag"].astype(float)
    ax[2,0].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J1831)):
 #   ax[2,0].vlines((J1831g.JD[peak_J1831[i]] - (2.458 * 10**6)), 13.45, (max(J1831g['Mag'])+0.1), "k", alpha=0.4)

ax[2,0].set_title('J183606-314826', y=1.0, pad=padnum, size=titlesize)
ax[2,0].set_ylim(13.45,(max(J1831g['Mag'])+0.1))
ax[2,0].set_yticks(np.linspace(13.6, 14.2, 7))

# Subfig 8 (J190316-195739)	(515396514761)
cams = J1919g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ1919 = J1919g.loc[J1919g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ1919["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ1919["Mag"].astype(float)
    ax[2,1].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J1919)):
 #   ax[2,1].vlines((J1919g.JD[peak_J1919[i]] - (2.458 * 10**6)), 13.25, (max(J1919g['Mag'])+0.15), "k", alpha=0.4)

ax[2,1].set_title('J190316-195739', y=1.0, pad=padnum, size=titlesize)
ax[2,1].set_ylim(13.25,(max(J1919g['Mag'])+0.15))
ax[2,1].set_yticks(np.linspace(13.4, 14, 7))

# Subfig 9 (J205245-713514)	(463856535113)
cams = J2071g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ2071 = J2071g.loc[J2071g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ2071["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ2071["Mag"].astype(float)
    ax[2,2].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J2071)):
 #   ax[2,2].vlines((J2071g.JD[peak_J2071[i]] - (2.458 * 10**6)), 13.15, (max(J2071g['Mag'])+0.15), "k", alpha=0.4)

ax[2,2].set_title('J205245-713514', y=1.0, pad=padnum, size=titlesize)
ax[2,2].set_ylim(13.15,(max(J2071g['Mag'])+0.15))
ax[2,2].set_yticks(np.linspace(13.3, 13.8, 6))

# Subfig 10 (J212132+480140) (120259184943)
cams = J2148g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ2148 = J2148g.loc[J2148g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ2148["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ2148["Mag"].astype(float)
    ax[3,0].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J2148)):
 #   ax[3,0].vlines((J2148g.JD[peak_J2148[i]] - (2.458 * 10**6)), 12.9, (max(J2148g['Mag'])+0.1), "k", alpha=0.4)

ax[3,0].set_title('J212132+480140', y=1.0, pad=padnum, size=titlesize)
ax[3,0].set_ylim(12.9,(max(J2148g['Mag'])+0.1))
ax[3,0].set_yticks(np.linspace(13, 13.5, 6))

# Subfig 11 (J225702+562312) (25770019815)
cams = J225623g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ225623 = J225623g.loc[J225623g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ225623["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ225623["Mag"].astype(float)
    ax[3,1].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J225623)):
 #   ax[3,1].vlines((J225623g.JD[peak_J225623[i]] - (2.458 * 10**6)), 13.55, (max(J225623g['Mag'])+0.1), "k", alpha=0.4)

ax[3,1].set_title('J225702+562312', y=1.0, pad=padnum, size=titlesize)
ax[3,1].set_ylim(13.55,(max(J225623g['Mag'])+0.1))
ax[3,1].set_yticks(np.linspace(13.7, 14.2, 6))

# Subfig 12 (J124745-622756) (515397118400)
cams = J1262g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ1262 = J1262g.loc[J1262g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ1262["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ1262["Mag"].astype(float)
    ax[3,2].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J1262)):
 #   ax[3,2].vlines((J1262g.JD[peak_J1262[i]] - (2.458 * 10**6)), 13.3, (max(J1262g['Mag'])+0.1), "k", alpha=0.4)

ax[3,2].set_title('J124745-622756', y=1.0, pad=padnum, size=titlesize)
ax[3,2].set_ylim(13.3,(max(J1262g['Mag'])+0.1))
ax[3,2].set_yticks(np.linspace(13.4, 13.9, 6))

# Subfig 13 (J160757-574540) (661425129485)
cams = J1657g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ1657 = J1657g.loc[J1657g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ1657["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ1657["Mag"].astype(float)
    ax[4,0].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J1657)):
 #   ax[4,0].vlines((J1657g.JD[peak_J1657[i]] - (2.458 * 10**6)), 13.65, (max(J1657g['Mag'])+0.1), "k", alpha=0.4)

ax[4,0].set_title('J160757-574540', y=1.0, pad=padnum, size=titlesize)
ax[4,0].set_ylim(13.65,(max(J1657g['Mag'])+0.1))
ax[4,0].set_yticks(np.linspace(13.8, 14.2, 5))

# Subfig 14 (J175912-120956) (326417831663)
cams = J1712g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ1712 = J1712g.loc[J1712g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ1712["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ1712["Mag"].astype(float)
    ax[4,1].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J1712)):
 #   ax[4,1].vlines((J1712g.JD[peak_J1712[i]] - (2.458 * 10**6)), 13.2, (max(J1712g['Mag'])+0.1), "k", alpha=0.4)

ax[4,1].set_title('J175912-120956', y=1.0, pad=padnum, size=titlesize)
ax[4,1].set_ylim(13.2,(max(J1712g['Mag'])+0.1))
ax[4,1].set_yticks(np.linspace(13.3, 13.9, 4))

# Subfig 15 (J042214+152530) (377957522430)
cams = J0415g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ0415 = J0415g.loc[J0415g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ0415["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ0415["Mag"].astype(float)
    ax[4,2].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J0415)):
 #   ax[4,2].vlines((J0415g.JD[peak_J0415[i]] - (2.458 * 10**6)), 12.7, (max(J0415g['Mag'])+0.2), "k", alpha=0.4)

ax[4,2].set_title('J042214+152530', y=1.0, pad=padnum, size=titlesize)
ax[4,2].set_ylim(12.7,(max(J0415g['Mag'])+0.2))
ax[4,2].set_yticks(np.linspace(13, 14.2, 7))

# Subfig 16 (J080327-261620) (601296043597)
cams = J0826g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ0826 = J0826g.loc[J0826g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ0826["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ0826["Mag"].astype(float)
    ax[5,0].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J0826)):
 #   ax[5,0].vlines((J0826g.JD[peak_J0826[i]] - (2.458 * 10**6)), 12.85, (max(J0826g['Mag'])+0.15), "k", alpha=0.4)

ax[5,0].set_title('J080327-261620', y=1.0, pad=padnum, size=titlesize)
ax[5,0].set_ylim(12.85,(max(J0826g['Mag'])+0.15))
ax[5,0].set_yticks(np.linspace(13, 13.7, 8))

# Subfig 17 (J174328+343315) (223339338105)
cams = J1734g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ1734 = J1734g.loc[J1734g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ1734["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ1734["Mag"].astype(float)
    ax[5,1].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J1734)):
 #   ax[5,1].vlines((J1734g.JD[peak_J1734[i]] - (2.458 * 10**6)), 13.1, (max(J1734g['Mag'])+0.1), "k", alpha=0.4)

ax[5,1].set_title('J174328+343315', y=1.0, pad=padnum, size=titlesize)
ax[5,1].set_ylim(13.1,(max(J1734g['Mag'])+0.1))
ax[5,1].set_yticks(np.linspace(13.2, 13.7, 6))

# Subfig 18 (J202402+383938) (42950993887)
cams = J2038g["Camera"]
camtype = np.unique(cams)
camnum = len(camtype)

for i in range(0,camnum):
    camJ2038 = J2038g.loc[J2038g["Camera"] == camtype[i]].reset_index(drop=True)
    camjd = camJ2038["JD"].astype(float) - (2.458 * 10 ** 6)
    cammag = camJ2038["Mag"].astype(float)
    ax[5,2].scatter(camjd, cammag, color=colors[i], alpha=0.6, marker='.')

#for i in range(len(peak_J2038)):
 #   ax[5,2].vlines((J2038g.JD[peak_J2038[i]] - (2.458 * 10**6)), 12.6, (max(J2038g['Mag'])+0.15), "k", alpha=0.4)

ax[5,2].set_title('J202402+383938', y=1.0, pad=padnum, size=titlesize)
ax[5,2].set_ylim(12.6,(max(J2038g['Mag'])+0.15))
ax[5,2].set_yticks(np.linspace(12.8, 13.6, 5))

for axe in ax.flatten():
    axe.invert_yaxis()
    axe.minorticks_on()
    axe.tick_params(axis='x', direction='in', top=False, labelbottom=True, bottom=True, pad=-25, labelsize=15)
    axe.tick_params(axis='y', direction='in', right=False, pad=-45, labelsize=15)
    axe.tick_params('both', length=8, width=2, which='major')
    axe.tick_params('both', direction='in', length=5, width=1.3, which='minor')
    axe.yaxis.set_minor_locator(tick.MultipleLocator(0.05))
    secax = axe.secondary_xaxis('top', functions=(jd_to_year,year_to_jd))
    secax.set_xticks(np.linspace(2018, 2024, 7))
    secax.xaxis.set_tick_params(direction='in', labelsize=15, pad=-20, length=6, width=1.5) 
    for axis in ['top', 'bottom', 'left', 'right']:
        axe.spines[axis].set_linewidth(2)

fig.supxlabel('Julian Date - $2458000$ [d]', fontsize=50, y=0.075)
fig.supylabel('g [mag]', fontsize=50, x=0.08)
# Out:
# Text(0.08, 0.5, 'g [mag]')

# %% [markdown]
# fig = plt.figure(figsize=(24,28))
# gs = fig.add_gridspec(6,3,hspace=0,wspace=0)
# ax = gs.subplots(sharex=False,sharey=False)
#
# padnum = -30
#
# # Subfig 1 (J062510-075341)	(377958261591)
# J0607g = J0607g.loc[J0607g['JD'] > 700 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J0607g = J0607g.loc[J0607g['JD'] < 800 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J0607g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ0607 = J0607g.loc[J0607g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ0607["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ0607["Mag"].astype(float)
#     ax[0,0].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[0,0].set_title('J062510-075341', y=1.0, pad=padnum)
# ax[0,0].set_ylim(13.4,(max(J0607g['Mag'])+0.1))
# ax[0,0].set_yticks(np.linspace(13.5, 14.2, 8))
#
# # Subfig 2 (J073924-272916)	(438086977939)
# J0727g = J0727g.loc[J0727g['JD'] > 1900 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J0727g = J0727g.loc[J0727g['JD'] < 2100 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J0727g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ0727 = J0727g.loc[J0727g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ0727["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ0727["Mag"].astype(float)
#     ax[0,1].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[0,1].set_title('J073924-272916', y=1.0, pad=padnum)
# ax[0,1].set_ylim(12.8,(max(J0727g['Mag'])+0.1))
# ax[0,1].set_yticks(np.linspace(12.9, 13.3, 5))
#
# # Subfig 3 (J074007-161608)	(360777377116)
# J0716g = J0716g.loc[J0716g['Mag'] < 13.75].reset_index(drop=True)
# J0716g = J0716g.loc[J0716g['JD'] > 1800 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J0716g = J0716g.loc[J0716g['JD'] < 1900 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J0716g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ0716 = J0716g.loc[J0716g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ0716["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ0716["Mag"].astype(float)
#     ax[0,2].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[0,2].set_title('J074007-161608', y=1.0, pad=padnum)
# ax[0,2].set_ylim(12.9,(max(J0716g['Mag'])+0.1))
# ax[0,2].set_yticks(np.linspace(13, 13.4, 5))
#
# # Subfig 4 (J094848-545959)	(635655234580)
# J0954g = J0954g.loc[J0954g['JD'] > 500 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J0954g = J0954g.loc[J0954g['JD'] < 600 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J0954g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ0954 = J0954g.loc[J0954g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ0954["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ0954["Mag"].astype(float)
#     ax[1,0].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[1,0].set_title('J094848-545959', y=1.0, pad=padnum)
# ax[1,0].set_ylim(12.9,(max(J0954g['Mag'])+0.1))
# ax[1,0].set_yticks(np.linspace(13, 13.4, 5))
#
# # Subfig 5 (J162209-444247)	(412317159120)
# J1644g = J1644g.loc[J1644g['JD'] > 2000 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J1644g = J1644g.loc[J1644g['JD'] < 2100 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J1644g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ1644 = J1644g.loc[J1644g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ1644["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ1644["Mag"].astype(float)
#     ax[1,1].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[1,1].set_title('J162209-444247', y=1.0, pad=padnum)
# #ax[1,1].set_ylim(13.8,(max(J0716g['Mag'])+0.1))
# #ax[1,1].set_yticks(np.linspace(14.1, 15.7, 5))
#
# # Subfig 6 (J183210-173432)	(317827964025)
# J1817g = J1817g.loc[J1817g['JD'] > 300 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J1817g = J1817g.loc[J1817g['JD'] < 500 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J1817g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ1817 = J1817g.loc[J1817g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ1817["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ1817["Mag"].astype(float)
#     ax[1,2].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[1,2].set_title('J183210-173432', y=1.0, pad=padnum)
# #ax[1,2].set_ylim(13.8,(max(J0716g['Mag'])+0.1))
# ax[1,2].set_yticks(np.linspace(12.7, 13, 4))
#
# # Subfig 7 (J183606-314826)	(438086901547)
# J1831g = J1831g.loc[J1831g['Mag'] < 14.5].reset_index(drop=True)
# J1831g = J1831g.loc[J1831g['JD'] > 1600 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J1831g = J1831g.loc[J1831g['JD'] < 1700 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J1831g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ1831 = J1831g.loc[J1831g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ1831["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ1831["Mag"].astype(float)
#     ax[2,0].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[2,0].set_title('J183606-314826', y=1.0, pad=padnum)
# ax[2,0].set_ylim(13.6,(max(J1831g['Mag'])+0.1))
# ax[2,0].set_yticks(np.linspace(13.7, 14.2, 6))
#
# # Subfig 8 (J190316-195739)	(515396514761)
# J1919g = J1919g.loc[J1919g['JD'] > 650 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J1919g = J1919g.loc[J1919g['JD'] < 750 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J1919g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ1919 = J1919g.loc[J1919g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ1919["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ1919["Mag"].astype(float)
#     ax[2,1].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[2,1].set_title('J190316-195739', y=1.0, pad=padnum)
# ax[2,1].set_ylim(13.4,(max(J1919g['Mag'])+0.1))
# ax[2,1].set_yticks(np.linspace(13.5, 14, 6))
#
# # Subfig 9 (J205245-713514)	(463856535113)
# J2071g = J2071g.loc[J2071g['JD'] > 2000 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J2071g = J2071g.loc[J2071g['JD'] < 2100 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J2071g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ2071 = J2071g.loc[J2071g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ2071["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ2071["Mag"].astype(float)
#     ax[2,2].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[2,2].set_title('J205245-713514', y=1.0, pad=padnum)
# ax[2,2].set_ylim(13.2,(max(J2071g['Mag'])+0.1))
# ax[2,2].set_yticks(np.linspace(13.3, 13.8, 6))
#
# # Subfig 10 (J212132+480140) (120259184943)
# J2148g = J2148g.loc[J2148g['JD'] > 1400 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J2148g = J2148g.loc[J2148g['JD'] < 1600 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J2148g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ2148 = J2148g.loc[J2148g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ2148["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ2148["Mag"].astype(float)
#     ax[3,0].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[3,0].set_title('J212132+480140', y=1.0, pad=padnum)
# ax[3,0].set_ylim(12.9,(max(J2148g['Mag'])+0.1))
# ax[3,0].set_yticks(np.linspace(13, 13.5, 6))
#
# # Subfig 11 (J225702+562312) (25770019815)
# J225623g = J225623g.loc[J225623g['JD'] > 600 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J225623g = J225623g.loc[J225623g['JD'] < 700 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J225623g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ225623 = J225623g.loc[J225623g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ225623["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ225623["Mag"].astype(float)
#     ax[3,1].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[3,1].set_title('J225702+562312', y=1.0, pad=padnum)
# ax[3,1].set_ylim(13.6,(max(J225623g['Mag'])+0.1))
# ax[3,1].set_yticks(np.linspace(13.7, 14.2, 6))
#
# # Subfig 12 (J124745-622756) (515397118400)
# J1262g = J1262g.loc[J1262g['JD'] > 2400 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J1262g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ1262 = J1262g.loc[J1262g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ1262["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ1262["Mag"].astype(float)
#     ax[3,2].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[3,2].set_title('J124745-622756', y=1.0, pad=padnum)
# #ax[3,2].set_ylim(13.8,(max(J0716g['Mag'])+0.1))
# #ax[3,2].set_yticks(np.linspace(14.1, 15.7, 5))
#
# # Subfig 13 (J160757-574540) (661425129485)
# J1657g = J1657g.loc[J1657g['JD'] > 2400 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J1657g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ1657 = J1657g.loc[J1657g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ1657["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ1657["Mag"].astype(float)
#     ax[4,0].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[4,0].set_title('J160757-574540', y=1.0, pad=padnum)
# ax[4,0].set_ylim(13.7,(max(J1657g['Mag'])+0.1))
# ax[4,0].set_yticks(np.linspace(13.8, 14.2, 5))
#
# # Subfig 14 (J175912-120956) (326417831663)
# J1712g = J1712g.loc[J1712g['JD'] > 1650 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J1712g = J1712g.loc[J1712g['JD'] < 1750 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J1712g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ1712 = J1712g.loc[J1712g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ1712["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ1712["Mag"].astype(float)
#     ax[4,1].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[4,1].set_title('J175912-120956', y=1.0, pad=padnum)
# #ax[4,1].set_ylim(13.8,(max(J0716g['Mag'])+0.1))
# ax[4,1].set_yticks(np.linspace(13.4, 13.9, 6))
#
# # Subfig 15 (J042214+152530) (377957522430)
# J0415g = J0415g.loc[J0415g['JD'] > 1700 + (2.458 * 10 ** 6)].reset_index(drop=True)
# J0415g = J0415g.loc[J0415g['JD'] < 2000 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J0415g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ0415 = J0415g.loc[J0415g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ0415["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ0415["Mag"].astype(float)
#     ax[4,2].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[4,2].set_title('J042214+152530', y=1.0, pad=padnum)
# ax[4,2].set_ylim(12.9,(max(J0415g['Mag'])+0.1))
# ax[4,2].set_yticks(np.linspace(13.2, 14.2, 6))
#
# # Subfig 16 (J080327-261620) (601296043597)
# J0826g = J0826g.loc[J0826g['JD'] > 1500 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J0826g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ0826 = J0826g.loc[J0826g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ0826["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ0826["Mag"].astype(float)
#     ax[5,0].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[5,0].set_title('J080327-261620', y=1.0, pad=padnum)
# ax[5,0].set_ylim(13,(max(J0826g['Mag'])+0.1))
# ax[5,0].set_yticks(np.linspace(13.1, 13.7, 7))
#
# # Subfig 17 (J174328+343315) (223339338105)
# J1734g = J1734g.loc[J1734g['JD'] < 1000 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J1734g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ1734 = J1734g.loc[J1734g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ1734["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ1734["Mag"].astype(float)
#     ax[5,1].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[5,1].set_title('J174328+343315', y=1.0, pad=padnum)
# #ax[5,1].set_ylim(13.8,(max(J0716g['Mag'])+0.1))
# ax[5,1].set_yticks(np.linspace(13.3, 13.6, 4))
#
# # Subfig 18 (J202402+383938) (42950993887)
# J2038g = J2038g.loc[J2038g['JD'] < 2000 + (2.458 * 10 ** 6)].reset_index(drop=True)
#
# cams = J2038g["Camera"]
# camtype = np.unique(cams)
# camnum = len(camtype)
#
# for i in range(0,camnum):
#     camJ2038 = J2038g.loc[J2038g["Camera"] == camtype[i]].reset_index(drop=True)
#     camjd = camJ2038["JD"].astype(float) - (2.458 * 10 ** 6)
#     cammag = camJ2038["Mag"].astype(float)
#     ax[5,2].scatter(camjd, cammag, color=colors[i], alpha=0.6)
#
# ax[5,2].set_title('J202402+383938', y=1.0, pad=padnum)
# #ax[5,2].set_ylim(13.8,(max(J0716g['Mag'])+0.1))
# #ax[5,2].set_yticks(np.linspace(14.1, 15.7, 5))
#
# for axe in ax.flatten():
#     axe.invert_yaxis()
#     axe.tick_params(axis='x', direction='in', top=False, labelbottom=True, bottom=True, pad=-15, labelsize=12)
#     axe.tick_params(axis='y', direction='in', right=False, pad=-35, labelsize=12)
#     #secax = axe.secondary_xaxis('top', functions=(jd_to_year,year_to_jd))
#     #secax.xaxis.set_tick_params(direction='in', labelsize=12, pad=-15)
#
# fig.supxlabel('Julian Date - $2458000$ [d]', fontsize=50, y=0.075)
# fig.supylabel('g [mag]', fontsize=50, x=0.08)
